# %% [markdown]
# <a href="https://colab.research.google.com/github/Abhishek-jakhar/Machine_learning/blob/main/Ridge_regularization.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
from sklearn.datasets import load_diabetes
data = load_diabetes()

# %%
print(data.DESCR) # description of dataset
# Out:
# .. _diabetes_dataset:
#
# Diabetes dataset
# ----------------
#
# Ten baseline variables, age, sex, body mass index, average blood
# pressure, and six blood serum measurements were obtained for each of n =
# 442 diabetes patients, as well as the response of interest, a
# quantitative measure of disease progression one year after baseline.
#
# **Data Set Characteristics:**
#
# :Number of Instances: 442
#
# :Number of Attributes: First 10 columns are numeric predictive values
#
# :Target: Column 11 is a quantitative measure of disease progression one year after baseline
#
# :Attribute Information:
#     - age     age in years
#     - sex
#     - bmi     body mass index
#     - bp      average blood pressure
#     - s1      tc, total serum cholesterol
#     - s2      ldl, low-density lipoproteins
#     - s3      hdl, high-density lipoproteins
#     - s4      tch, total cholesterol / HDL
#     - s5      ltg, possibly log of serum triglycerides level
# ...

# %%
x = data.data
y = data.target

# %%
from sklearn.model_selection import train_test_split
X_train, X_test ,y_train,y_test = train_test_split(x,y,test_size=0.2,random_state=2)

# %%
from sklearn.linear_model import LinearRegression
lr = LinearRegression()
lr.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
y_pred = lr.predict(X_test)

# %%
from sklearn.metrics import r2_score , mean_squared_error

# %%
print("the r2 score is: ",r2_score(y_test,y_pred))
# Out:
# the r2 score is:  0.4399338661568968

# %%
print('RMSE is:',np.sqrt(mean_squared_error(y_test,y_pred)))
# Out:
# RMSE is: 55.627840795469155

# %% [markdown]
# # **Now we will do the same work using the ridge regularization**

# %%
from sklearn.linear_model import Ridge
rg = Ridge(alpha=0.001)

# %%
rg.fit(X_train,y_train)
# Out:
# Ridge(alpha=0.001)

# %%
y_pred = rg.predict(X_test)

# %%
print("the r2 score is: ",r2_score(y_test,y_pred))
# Out:
# the r2 score is:  0.4408617113920028

# %%
from sklearn.linear_model import Lasso
l = Lasso(alpha = 0.002)

# %%
l.fit(X_train,y_train)
# Out:
# Lasso(alpha=0.002)

# %%
y_pred = rg.predict(X_test)

# %%
print("the r2 score is: ",r2_score(y_test,y_pred))
# Out:
# the r2 score is:  0.4408617113920028
